# %% [markdown]
# # Predição de Temperatura com MLP - TinyML
#
# **Projeto:** Sistema de Predição de Temperatura para Microcontroladores
#
# **Objetivo:** Prever a temperatura do sensor AHT20 em 5, 10 e 15 minutos no futuro
#
# **Sensores utilizados:**
# - AHT20: Temperatura e Umidade
# - BMP280: Temperatura e Pressão
#
# **Modelo:** MLP (Multi-Layer Perceptron) compatível com TensorFlow Lite Micro
#
# **Deploy:** Raspberry Pi Pico (RP2040)
#
# ---

# %% [markdown]
# # 1. Carregar os Dados
#
# ---

# %%
# Bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# TensorFlow e Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

# Sklearn para pré-processamento e métricas
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import os
import joblib

# Configuração de visualização
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (14, 6)

# Configurar seed para reprodutibilidade
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f'TensorFlow: {tf.__version__}')
print(f'Seed configurado: {SEED}')
# Out:
# TensorFlow: 2.20.0
# Seed configurado: 42

# %%
#Carregar o dataset de temperatura em lê csv
df_raw = pd.read_csv('data/temp.csv')
df_raw['Timestamp'] = pd.to_datetime(df_raw['Timestamp'])#converter coluna de timestamp para datetime
print(f'Shape original: {df_raw.shape}')
print(f'Colunas disponíveis: {list(df_raw.columns)}')
# Out:
# Shape original: (82430, 12)
# Colunas disponíveis: ['Timestamp', 'Temp_MPU6050_C', 'Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa', 'Temp_BMP180_C', 'Press_BMP180_hPa', 'Temp_DS18B20_C', 'Temp_NTC_C', 'Temp_DHT11_C', 'Umid_DHT11_pct']

# %%
#Selecionar apenas as features de interesse
features = ['Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa']
df = df_raw[['Timestamp'] + features].copy()

print(f'\nDataset filtrado:')
print(f'Shape: {df.shape}')
print(f'Features selecionadas: {features}')
print(f'Período dos dados: {df["Timestamp"].min()} até {df["Timestamp"].max()}')
print(f'\nPrimeiras linhas:')
df.head()
# Out:
# Dataset filtrado:
# Shape: (82430, 5)
# Features selecionadas: ['Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa']
# Período dos dados: 2025-08-31 22:31:02 até 2025-09-30 16:52:09
#
# Primeiras linhas:
#             Timestamp  Temp_AHT20_C  Umid_AHT20_pct  Temp_BMP280_C  \
# 0 2025-08-31 22:31:02         19.90           73.37          21.28
# 1 2025-08-31 22:31:33         19.97           75.57          21.48
# 2 2025-08-31 22:32:05         19.75           74.31          21.25
# 3 2025-08-31 22:32:36         19.55           74.77          21.07
# 4 2025-08-31 22:33:07         19.60           75.09          21.12
#
#    Press_BMP280_hPa
# 0            921.24
# 1            921.12
# 2            921.20
# 3            921.15
# 4            921.25

# %% [markdown]
# # 2. Pré-processamento dos Dados
#
# ---

# %%
# Criar df_clean 
df_clean = df.copy()

#: aplicar remoção de outliers 
for col in features:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]

print(f'Depois: {len(df_clean)} amostras')
removed = len(df) - len(df_clean)
print(f'Removidos: {removed} ({100*removed/len(df):.2f}%)')
# Out:
# Depois: 82430 amostras
# Removidos: 0 (0.00%)

# %% [markdown]
# ## 2.1. Criar Sequências Temporais
#
# **Conceito:** Transformar dados tabulares em sequências para MLP
#
# **Formato:**
# - Input (X): Janela de 10 timesteps com 4 features cada → achatado para vetor 1D (40 valores)
# - Output (y): Temperatura futura em 3 horizontes (5, 10, 15 minutos)
#
# **Exemplo:**
# ```
# X = [timestep_0, timestep_1, ..., timestep_9]  <- 10 timesteps passados (achatado: 40 features)
# y = [temp_t+10, temp_t+19, temp_t+29]           <- 3 previsões futuras
# ```

# %%
#Configurar parâmetros das sequências
WINDOW_SIZE = 10 #Tamanho janela
HORIZONS = [10, 19, 29] # tempo para cada previsao (5 minutos, 10 minutos, 15 minutos)
print(f'  - Prever temperatura em {HORIZONS[0] * 31 / 60:.1f}, {HORIZONS[1] * 31 / 60:.1f} e {HORIZONS[2] * 31 / 60:.1f} minutos')
# Out:
#   - Prever temperatura em 5.2, 9.8 e 15.0 minutos

# %%
def create_sequences(data, window_size, horizons):
    """
    Criar sequências temporais para treinamento
    
    Parâmetros:
    - data: DataFrame com os dados
    - window_size: tamanho da janela de observação
    - horizons: lista de horizontes de previsão

    Retorna:
    - X: array 3D (samples, timesteps, features) -> Amostras e janelas temporais
    - y: array 2D (samples, horizons) -> TARGET É APENAS OS VALORES DE PREVISAO PARA 5, 10 E 15 MINUTOS
    """
    X, y = [], [] #armazenar x e y
    target = 'Temp_AHT20_C'
    
    for i in range(len(data) - window_size - max(horizons)): #itera pelos dados, parando antes do final para garantir espaço suficiente
        #para a janela + horizonte máximo de previsão
        X.append(data.iloc[i:i+window_size][features].values) #Seleciona apenas as colunas de features 
        #Pega uma janela de tamanho window_size começando na posição i
        y.append([data.iloc[i+window_size+h][target] for h in horizons])#Para cada horizonte em horizons (ex: [0, 5, 10]), pega o valor do target no futuro
        #i+window_size+h = posição após a janela + horizonte
        #Cria uma lista com múltiplos targets (previsões para diferentes tempos futuros)
    
    return np.array(X), np.array(y)

X, y = create_sequences(df_clean, WINDOW_SIZE, HORIZONS) #APLICA FUNÇÃO

print(f'\nX shape: {X.shape}')
print(f'  - {X.shape[0]} amostras')
print(f'  - {X.shape[1]} timesteps por amostra')
print(f'  - {X.shape[2]} features por timestep')
print(f'\ny shape: {y.shape}')
print(f'  - {y.shape[0]} amostras')
print(f'  - {y.shape[1]} horizontes de previsão')
# Out:
# X shape: (82391, 10, 4)
#   - 82391 amostras
#   - 10 timesteps por amostra
#   - 4 features por timestep
#
# y shape: (82391, 3)
#   - 82391 amostras
#   - 3 horizontes de previsão

# %% [markdown]
# ## 2.2. Divisão em Treino, Validação e Teste
#
# **Divisão:**
# - Treino: 70% dos dados (para treinar o modelo)
# - Validação: 15% dos dados (para ajustar hiperparâmetros)
# - Teste: 15% dos dados (para avaliar desempenho final)

# %%
#Dividir dados em treino, validação e teste
train_size = int(0.7 * len(X))
val_size = int(0.85 * len(X))

X_train, y_train = X[:train_size], y[:train_size]
X_val, y_val = X[train_size:val_size], y[train_size:val_size]
X_test, y_test = X[val_size:], y[val_size:]

print('Dados divididos:')
print(f'  Treino:    {len(X_train):6d} amostras ({100*len(X_train)/len(X):.1f}%)')
print(f'  Validação: {len(X_val):6d} amostras ({100*len(X_val)/len(X):.1f}%)')
print(f'  Teste:     {len(X_test):6d} amostras ({100*len(X_test)/len(X):.1f}%)')
# Out:
# Dados divididos:
#   Treino:     57673 amostras (70.0%)
#   Validação:  12359 amostras (15.0%)
#   Teste:      12359 amostras (15.0%)

# %% [markdown]
# ## 2.3. Normalização dos Dados
#
# **Por que normalizar?**
# - Features têm escalas diferentes (temperatura ~20°C, pressão ~920 hPa)
# - Redes neurais aprendem melhor com dados normalizados
# - Evita que features com valores grandes dominem o treinamento
#
# **Método:** StandardScaler (Z-score normalization)
# - Transforma dados para média = 0 e desvio padrão = 1
# - Fórmula: (x - média) / desvio_padrão

# %%
scaler = StandardScaler()# Normalizar dados usando StandardScaler

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #Transforma dados 3D (amostras, timesteps, features) em 2D (amostras*timesteps, features)
#Necessário porque StandardScaler trabalha com dados 2D
scaler.fit(X_train_reshaped) #Calcula média e desvio padrão de cada feature usando APENAS dados de treino
#Aprende os parâmetros de normalização

#aplica (x - média) / desvio para cada feature
# Processo: reshape para 2D → normaliza → reshape de volta para 3D
#Os MESMOS parâmetros aprendidos no treino são aplicados em val e test
X_train_scaled = scaler.transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_val_scaled = scaler.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
print(f'\nParâmetros do scaler:')
print(f'  Média (treino): {X_train_scaled.mean():.6f}')
print(f'  Desvio (treino): {X_train_scaled.std():.6f}')
print(f'\nMédias por feature:')
for i, name in enumerate(features):
    print(f'  {name:20s}: mean={scaler.mean_[i]:8.4f}, std={scaler.scale_[i]:8.4f}')
# Out:
# Parâmetros do scaler:
#   Média (treino): 0.000000
#   Desvio (treino): 1.000000
#
# Médias por feature:
#   Temp_AHT20_C        : mean= 20.2761, std=  3.2941
#   Umid_AHT20_pct      : mean= 66.7186, std= 13.4807
#   Temp_BMP280_C       : mean= 21.7595, std=  3.1919
#   Press_BMP280_hPa    : mean=918.0153, std=  2.1066

# %% [markdown]
# - Até aqui tudo igual ao modelo Conv1D

# %% [markdown]
# # 3. Construção e Treinamento do Modelo
#
# ---

# %% [markdown]
# ## 3.1. Arquitetura do Modelo MLP
#
# **Por que MLP?**
# - Arquitetura simples e eficiente
# - Baixo custo computacional
# - Compatível com TensorFlow Lite Micro
# - Serve como baseline para comparação com CNN 1D
#
# **Arquitetura:**
# ```
# Input (10 timesteps × 4 features)
#     |
# Flatten (40 valores)
#     |
# Dense(32) + ReLU + Dropout(0.2)
#     |
# Dense(16) + ReLU + Dropout(0.2)
#     |
# Dense(3) [Output: 3 previsões]
# ```

# %%
# Construir modelo MLP
model = Sequential([
    # Camada de entrada - achata a janela temporal em um vetor 1D
    Input(shape=(WINDOW_SIZE, 4)),  #Entrada: janela temporal com 4 features
    Flatten(name='flatten'),  # (10, 4) -> (40,) achata timesteps x features
    
    # Primeira camada densa
    Dense(32, activation='relu',
          kernel_regularizer=regularizers.l2(0.0001),#Regularização L2 para evitar overfitting
          name='dense_1'),
    
    #Dropout para reduzir overfitting (desliga 20% dos neurônios)
    Dropout(0.2, name='dropout_1'),
    
    # Segunda camada densa
    Dense(16, activation='relu',
          kernel_regularizer=regularizers.l2(0.0001),
          name='dense_2'),
    
    #Segundo dropout
    Dropout(0.2, name='dropout_2'),
    
    #Camada de saída - 3 valores (previsões para 3 horizontes temporais)
    Dense(3, activation='linear', name='output')
], name='MLP_Temperature')

# Compilar modelo
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='mse',
    metrics=['mae']
)

print('\nArquitetura:')
model.summary()

print(f'\nTotal de parâmetros: {model.count_params():,}')
# Out:
# Arquitetura:
# Model: "MLP_Temperature"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 40)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,891 (7.39 KB)
#  Trainable params: 1,891 (7.39 KB)
#  Non-trainable params: 0 (0.00 B)
# Total de parâmetros: 1,891

# %% [markdown]
# O MLP (Flatten + Dense) achata a janela de 10 timesteps em um vetor de 40 valores e processa tudo de uma vez pelas camadas densas, tratando cada entrada de forma independente sem considerar a ordem temporal. Já a Conv1D aplica filtros convolucionais que deslizam sobre os timesteps, capturando padrões locais e sequenciais nos dados (ex: tendências de subida/descida de temperatura entre timesteps vizinhos). Além disso, a Conv1D usa GlobalAveragePooling para comprimir a informação antes das camadas densas, enquanto o MLP depende do Flatten que gera mais conexões e pode ter mais parâmetros mesmo com menos camadas.

# %% [markdown]
# ## 3.2. Configurar Callbacks
#
# **Callbacks** são funções que executam durante o treinamento:
#
# 1. **EarlyStopping**: Para o treinamento se a validação não melhorar
# 2. **ReduceLROnPlateau**: Reduz learning rate quando estagnar

# %%
# Configurar callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=50, #aguarda 50 epocas sem melhora no val_loss antes de parar
        restore_best_weights=True, #restaura pesos da melhor epoca
        verbose=1#mostra quando para
    ), 
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5, #reduz learning rate pela metade
        patience=20, #aguarda 20 epoca sem melhorar antes de reduzir
        min_lr=1e-7, #minimo
        verbose=1 #mostrar quando reduzir
    )
]

# %% [markdown]
# ## 3.3. Treinar o Modelo

# %%
history = model.fit( #treinamento modelo
    X_train_scaled, y_train, # x e y de treino sendo x o normalizado
    validation_data=(X_val_scaled, y_val), #dados de validação
    epochs=300, #300 epoca
    batch_size=512,#Pega 512 amostras do dataset, gradiente mais estavel
    callbacks=callbacks, #Callbacks mostrado acima
    verbose=1 #mostra andamento
)
# Out:
# Epoch 1/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 353.8356 - mae: 18.4374 - val_loss: 294.3209 - val_mae: 16.9620 - learning_rate: 5.0000e-04
# Epoch 2/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 164.0747 - mae: 11.4802 - val_loss: 145.5414 - val_mae: 10.7916 - learning_rate: 5.0000e-04
# Epoch 3/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 117.3257 - mae: 9.2743 - val_loss: 118.9397 - val_mae: 9.6635 - learning_rate: 5.0000e-04
# Epoch 4/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 97.7570 - mae: 8.3558 - val_loss: 91.7907 - val_mae: 8.4150 - learning_rate: 5.0000e-04
# Epoch 5/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 77.9174 - mae: 7.3451 - val_loss: 64.9643 - val_mae: 6.8772 - learning_rate: 5.0000e-04
# Epoch 6/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.3595 - mae: 6.6323 - val_loss: 46.7996 - val_mae: 5.6894 - learning_rate: 5.0000e-04
# Epoch 7/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 56.3825 - mae: 6.1939 - val_loss: 36.3143 - val_mae: 5.0034 - learning_rate: 5.0000e-04
# Epoch 8/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 48.3034 - mae: 5.7176 - val_loss: 26.0449 - val_mae: 4.2484 - learning_rate: 5.0000e-04
# Epoch 9/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 40.8264 - mae: 5.2433 - val_loss: 15.8644 - val_mae: 3.3252 - learning_rate: 5.0000e-04
# Epoch 10/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 32.7147 - mae: 4.6544 - val_loss: 8.5466 - val_mae: 2.4664 - learning_rate: 5.0000e-04
# Epoch 11/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 26.1105 - mae: 4.1046 - val_loss: 5.0439 - val_mae: 1.8780 - learning_rate: 5.0000e-04
# Epoch 12/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 22.0125 - mae: 3.7322 - val_loss: 2.9118 - val_mae: 1.4173 - learning_rate: 5.0000e-04
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.9983 - mae: 3.5527 - val_loss: 1.7700 - val_mae: 1.1330 - learning_rate: 5.0000e-04
# Epoch 14/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 18.6491 - mae: 3.4204 - val_loss: 1.2072 - val_mae: 0.9434 - learning_rate: 5.0000e-04
# Epoch 15/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 17.9899 - mae: 3.3505 - val_loss: 0.9343 - val_mae: 0.7954 - learning_rate: 5.0000e-04
# Epoch 16/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.3300 - mae: 3.2943 - val_loss: 0.9027 - val_mae: 0.8321 - learning_rate: 5.0000e-04
# Epoch 17/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.9155 - mae: 3.2479 - val_loss: 0.8654 - val_mae: 0.8134 - learning_rate: 5.0000e-04
# Epoch 18/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.5379 - mae: 3.2070 - val_loss: 0.6685 - val_mae: 0.7425 - learning_rate: 5.0000e-04
# Epoch 19/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 16.1348 - mae: 3.1705 - val_loss: 0.6436 - val_mae: 0.7370 - learning_rate: 5.0000e-04
# Epoch 20/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.9536 - mae: 3.1500 - val_loss: 0.6408 - val_mae: 0.7323 - learning_rate: 5.0000e-04
# Epoch 21/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.5546 - mae: 3.1085 - val_loss: 0.7612 - val_mae: 0.8153 - learning_rate: 5.0000e-04
# Epoch 22/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4741 - mae: 3.1017 - val_loss: 0.7573 - val_mae: 0.8033 - learning_rate: 5.0000e-04
# Epoch 23/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4074 - mae: 3.0866 - val_loss: 0.5834 - val_mae: 0.6953 - learning_rate: 5.0000e-04
# Epoch 24/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 15.1503 - mae: 3.0660 - val_loss: 0.7276 - val_mae: 0.7649 - learning_rate: 5.0000e-04
# Epoch 25/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.9142 - mae: 3.0446 - val_loss: 0.5782 - val_mae: 0.6813 - learning_rate: 5.0000e-04
# Epoch 26/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.7374 - mae: 3.0251 - val_loss: 0.5530 - val_mae: 0.6761 - learning_rate: 5.0000e-04
# Epoch 27/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.6509 - mae: 3.0174 - val_loss: 0.6211 - val_mae: 0.7199 - learning_rate: 5.0000e-04
# Epoch 28/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.4283 - mae: 2.9930 - val_loss: 0.5715 - val_mae: 0.6932 - learning_rate: 5.0000e-04
# Epoch 29/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 14.4114 - mae: 2.9929 - val_loss: 0.4385 - val_mae: 0.5945 - learning_rate: 5.0000e-04
# Epoch 30/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.2300 - mae: 2.9743 - val_loss: 0.5422 - val_mae: 0.6546 - learning_rate: 5.0000e-04
# Epoch 31/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 14.1883 - mae: 2.9601 - val_loss: 0.5802 - val_mae: 0.7010 - learning_rate: 5.0000e-04
# Epoch 32/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.0717 - mae: 2.9494 - val_loss: 0.7085 - val_mae: 0.7514 - learning_rate: 5.0000e-04
# Epoch 33/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9312 - mae: 2.9380 - val_loss: 0.5370 - val_mae: 0.6536 - learning_rate: 5.0000e-04
# Epoch 34/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.7797 - mae: 2.9253 - val_loss: 0.6409 - val_mae: 0.7391 - learning_rate: 5.0000e-04
# Epoch 35/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7750 - mae: 2.9239 - val_loss: 0.5740 - val_mae: 0.6991 - learning_rate: 5.0000e-04
# Epoch 36/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.6827 - mae: 2.9066 - val_loss: 0.6398 - val_mae: 0.7330 - learning_rate: 5.0000e-04
# Epoch 37/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.5118 - mae: 2.8901 - val_loss: 0.6021 - val_mae: 0.7021 - learning_rate: 5.0000e-04
# Epoch 38/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.5607 - mae: 2.8909 - val_loss: 0.6946 - val_mae: 0.7744 - learning_rate: 5.0000e-04
# Epoch 39/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4848 - mae: 2.8833 - val_loss: 0.4280 - val_mae: 0.5708 - learning_rate: 5.0000e-04
# Epoch 40/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.1996 - mae: 2.8509 - val_loss: 0.7070 - val_mae: 0.7471 - learning_rate: 5.0000e-04
# Epoch 41/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4046 - mae: 2.8727 - val_loss: 0.7053 - val_mae: 0.7411 - learning_rate: 5.0000e-04
# Epoch 42/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.2117 - mae: 2.8532 - val_loss: 0.3753 - val_mae: 0.5507 - learning_rate: 5.0000e-04
# Epoch 43/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.9809 - mae: 2.8233 - val_loss: 0.4878 - val_mae: 0.6409 - learning_rate: 5.0000e-04
# Epoch 44/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.7738 - mae: 2.7994 - val_loss: 0.6540 - val_mae: 0.7224 - learning_rate: 5.0000e-04
# Epoch 45/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.7786 - mae: 2.8080 - val_loss: 0.5852 - val_mae: 0.7029 - learning_rate: 5.0000e-04
# Epoch 46/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.6611 - mae: 2.7887 - val_loss: 0.6669 - val_mae: 0.7289 - learning_rate: 5.0000e-04
# Epoch 47/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.6258 - mae: 2.7883 - val_loss: 0.5304 - val_mae: 0.6710 - learning_rate: 5.0000e-04
# Epoch 48/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 12.5434 - mae: 2.7824 - val_loss: 0.4479 - val_mae: 0.6078 - learning_rate: 5.0000e-04
# Epoch 49/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.4321 - mae: 2.7673 - val_loss: 0.5615 - val_mae: 0.6975 - learning_rate: 5.0000e-04
# Epoch 50/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.3877 - mae: 2.7575 - val_loss: 0.6468 - val_mae: 0.7329 - learning_rate: 5.0000e-04
# Epoch 51/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.1470 - mae: 2.7270 - val_loss: 0.7756 - val_mae: 0.7966 - learning_rate: 5.0000e-04
# Epoch 52/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.0970 - mae: 2.7225 - val_loss: 0.5577 - val_mae: 0.6800 - learning_rate: 5.0000e-04
# Epoch 53/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 11.9620 - mae: 2.7073 - val_loss: 0.6196 - val_mae: 0.7146 - learning_rate: 5.0000e-04
# Epoch 54/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 11.9111 - mae: 2.7051 - val_loss: 0.7279 - val_mae: 0.7537 - learning_rate: 5.0000e-04
# Epoch 55/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.8403 - mae: 2.6915 - val_loss: 0.7249 - val_mae: 0.7815 - learning_rate: 5.0000e-04
# Epoch 56/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7503 - mae: 2.6766 - val_loss: 0.5920 - val_mae: 0.7009 - learning_rate: 5.0000e-04
# Epoch 57/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 11.5641 - mae: 2.6528 - val_loss: 0.5622 - val_mae: 0.6692 - learning_rate: 5.0000e-04
# Epoch 58/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.5265 - mae: 2.6481 - val_loss: 0.4747 - val_mae: 0.6338 - learning_rate: 5.0000e-04
# Epoch 59/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 11.3456 - mae: 2.6276 - val_loss: 0.7816 - val_mae: 0.8182 - learning_rate: 5.0000e-04
# Epoch 60/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.3106 - mae: 2.6255 - val_loss: 0.7985 - val_mae: 0.7824 - learning_rate: 5.0000e-04
# Epoch 61/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 11.1854 - mae: 2.6108 - val_loss: 0.5240 - val_mae: 0.6682 - learning_rate: 5.0000e-04
# Epoch 62/300
# 105/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1526 - mae: 2.6060
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 11.1183 - mae: 2.6034 - val_loss: 0.3959 - val_mae: 0.5695 - learning_rate: 5.0000e-04
# Epoch 63/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 10.8650 - mae: 2.5796 - val_loss: 0.4123 - val_mae: 0.5825 - learning_rate: 2.5000e-04
# Epoch 64/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10.8563 - mae: 2.5747 - val_loss: 0.4648 - val_mae: 0.6188 - learning_rate: 2.5000e-04
# Epoch 65/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10.7637 - mae: 2.5658 - val_loss: 0.5200 - val_mae: 0.6434 - learning_rate: 2.5000e-04
# Epoch 66/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 10.8519 - mae: 2.5733 - val_loss: 0.7156 - val_mae: 0.7770 - learning_rate: 2.5000e-04
# Epoch 67/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 10.5764 - mae: 2.5411 - val_loss: 0.6078 - val_mae: 0.7170 - learning_rate: 2.5000e-04
# Epoch 68/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 10.6480 - mae: 2.5472 - val_loss: 0.4614 - val_mae: 0.6170 - learning_rate: 2.5000e-04
# Epoch 69/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.6427 - mae: 2.5482 - val_loss: 0.5863 - val_mae: 0.6958 - learning_rate: 2.5000e-04
# Epoch 70/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.5467 - mae: 2.5373 - val_loss: 0.3980 - val_mae: 0.5646 - learning_rate: 2.5000e-04
# Epoch 71/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.5287 - mae: 2.5290 - val_loss: 0.3640 - val_mae: 0.5448 - learning_rate: 2.5000e-04
# Epoch 72/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10.4606 - mae: 2.5276 - val_loss: 0.6229 - val_mae: 0.7080 - learning_rate: 2.5000e-04
# Epoch 73/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.2614 - mae: 2.5051 - val_loss: 0.6532 - val_mae: 0.7260 - learning_rate: 2.5000e-04
# Epoch 74/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.2425 - mae: 2.5070 - val_loss: 0.4574 - val_mae: 0.6204 - learning_rate: 2.5000e-04
# Epoch 75/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.3254 - mae: 2.5089 - val_loss: 0.4888 - val_mae: 0.6262 - learning_rate: 2.5000e-04
# Epoch 76/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.2163 - mae: 2.4958 - val_loss: 0.5029 - val_mae: 0.6490 - learning_rate: 2.5000e-04
# Epoch 77/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1570 - mae: 2.4909 - val_loss: 0.7671 - val_mae: 0.7750 - learning_rate: 2.5000e-04
# Epoch 78/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.0580 - mae: 2.4778 - val_loss: 0.4919 - val_mae: 0.6374 - learning_rate: 2.5000e-04
# Epoch 79/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9573 - mae: 2.4685 - val_loss: 0.4496 - val_mae: 0.6013 - learning_rate: 2.5000e-04
# Epoch 80/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10.1424 - mae: 2.4872 - val_loss: 0.5431 - val_mae: 0.6513 - learning_rate: 2.5000e-04
# Epoch 81/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.9804 - mae: 2.4699 - val_loss: 0.5782 - val_mae: 0.6971 - learning_rate: 2.5000e-04
# Epoch 82/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.9242 - mae: 2.4636 - val_loss: 0.6161 - val_mae: 0.6829 - learning_rate: 2.5000e-04
# Epoch 83/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8466 - mae: 2.4487 - val_loss: 0.3172 - val_mae: 0.4938 - learning_rate: 2.5000e-04
# Epoch 84/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8184 - mae: 2.4499 - val_loss: 0.5613 - val_mae: 0.6868 - learning_rate: 2.5000e-04
# Epoch 85/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.6582 - mae: 2.4314 - val_loss: 0.5065 - val_mae: 0.6389 - learning_rate: 2.5000e-04
# Epoch 86/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.6558 - mae: 2.4315 - val_loss: 0.4394 - val_mae: 0.5936 - learning_rate: 2.5000e-04
# Epoch 87/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.6161 - mae: 2.4321 - val_loss: 0.5644 - val_mae: 0.6779 - learning_rate: 2.5000e-04
# Epoch 88/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.6516 - mae: 2.4354 - val_loss: 0.5256 - val_mae: 0.6658 - learning_rate: 2.5000e-04
# Epoch 89/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5908 - mae: 2.4276 - val_loss: 0.4304 - val_mae: 0.5941 - learning_rate: 2.5000e-04
# Epoch 90/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.5030 - mae: 2.4112 - val_loss: 0.3481 - val_mae: 0.5287 - learning_rate: 2.5000e-04
# Epoch 91/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4331 - mae: 2.4042 - val_loss: 0.4782 - val_mae: 0.6287 - learning_rate: 2.5000e-04
# Epoch 92/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4607 - mae: 2.4113 - val_loss: 0.4047 - val_mae: 0.5751 - learning_rate: 2.5000e-04
# Epoch 93/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.3845 - mae: 2.4007 - val_loss: 0.4948 - val_mae: 0.6363 - learning_rate: 2.5000e-04
# Epoch 94/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4594 - mae: 2.4106 - val_loss: 0.4346 - val_mae: 0.5916 - learning_rate: 2.5000e-04
# Epoch 95/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.3107 - mae: 2.3873 - val_loss: 0.4434 - val_mae: 0.6055 - learning_rate: 2.5000e-04
# Epoch 96/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.1738 - mae: 2.3795 - val_loss: 0.4384 - val_mae: 0.5908 - learning_rate: 2.5000e-04
# Epoch 97/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.2909 - mae: 2.3850 - val_loss: 0.2767 - val_mae: 0.4635 - learning_rate: 2.5000e-04
# Epoch 98/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.1506 - mae: 2.3719 - val_loss: 0.6496 - val_mae: 0.7158 - learning_rate: 2.5000e-04
# Epoch 99/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.1704 - mae: 2.3790 - val_loss: 0.3922 - val_mae: 0.5549 - learning_rate: 2.5000e-04
# Epoch 100/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.1989 - mae: 2.3778 - val_loss: 0.2579 - val_mae: 0.4424 - learning_rate: 2.5000e-04
# Epoch 101/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.1037 - mae: 2.3710 - val_loss: 0.5990 - val_mae: 0.6949 - learning_rate: 2.5000e-04
# Epoch 102/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.0640 - mae: 2.3597 - val_loss: 0.3731 - val_mae: 0.5521 - learning_rate: 2.5000e-04
# Epoch 103/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.0877 - mae: 2.3708 - val_loss: 0.3903 - val_mae: 0.5553 - learning_rate: 2.5000e-04
# Epoch 104/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9529 - mae: 2.3501 - val_loss: 0.4234 - val_mae: 0.5853 - learning_rate: 2.5000e-04
# Epoch 105/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0413 - mae: 2.3578 - val_loss: 0.3514 - val_mae: 0.5244 - learning_rate: 2.5000e-04
# Epoch 106/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9201 - mae: 2.3434 - val_loss: 0.5216 - val_mae: 0.6434 - learning_rate: 2.5000e-04
# Epoch 107/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8507 - mae: 2.3305 - val_loss: 0.4240 - val_mae: 0.5627 - learning_rate: 2.5000e-04
# Epoch 108/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6142 - mae: 2.3016 - val_loss: 0.3250 - val_mae: 0.4896 - learning_rate: 2.5000e-04
# Epoch 109/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5757 - mae: 2.2930 - val_loss: 0.3505 - val_mae: 0.5068 - learning_rate: 2.5000e-04
# Epoch 110/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4891 - mae: 2.2792 - val_loss: 0.5038 - val_mae: 0.6155 - learning_rate: 2.5000e-04
# Epoch 111/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2780 - mae: 2.2467 - val_loss: 0.4498 - val_mae: 0.5931 - learning_rate: 2.5000e-04
# Epoch 112/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1763 - mae: 2.2367 - val_loss: 0.4293 - val_mae: 0.5661 - learning_rate: 2.5000e-04
# Epoch 113/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1836 - mae: 2.2345 - val_loss: 0.2818 - val_mae: 0.4569 - learning_rate: 2.5000e-04
# Epoch 114/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.0937 - mae: 2.2178 - val_loss: 0.4915 - val_mae: 0.6221 - learning_rate: 2.5000e-04
# Epoch 115/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.0530 - mae: 2.2194 - val_loss: 0.3285 - val_mae: 0.5031 - learning_rate: 2.5000e-04
# Epoch 116/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0461 - mae: 2.2116 - val_loss: 0.3339 - val_mae: 0.4973 - learning_rate: 2.5000e-04
# Epoch 117/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9507 - mae: 2.1995 - val_loss: 0.3319 - val_mae: 0.5107 - learning_rate: 2.5000e-04
# Epoch 118/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8912 - mae: 2.1905 - val_loss: 0.2926 - val_mae: 0.4758 - learning_rate: 2.5000e-04
# Epoch 119/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9353 - mae: 2.1932 - val_loss: 0.3945 - val_mae: 0.5616 - learning_rate: 2.5000e-04
# Epoch 120/300
#  98/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9439 - mae: 2.1874
# Epoch 120: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9343 - mae: 2.1864 - val_loss: 0.3410 - val_mae: 0.5131 - learning_rate: 2.5000e-04
# Epoch 121/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7817 - mae: 2.1700 - val_loss: 0.2978 - val_mae: 0.4821 - learning_rate: 1.2500e-04
# Epoch 122/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8975 - mae: 2.1831 - val_loss: 0.3098 - val_mae: 0.4927 - learning_rate: 1.2500e-04
# Epoch 123/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7411 - mae: 2.1587 - val_loss: 0.3695 - val_mae: 0.5368 - learning_rate: 1.2500e-04
# Epoch 124/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7903 - mae: 2.1682 - val_loss: 0.3249 - val_mae: 0.5041 - learning_rate: 1.2500e-04
# Epoch 125/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8059 - mae: 2.1677 - val_loss: 0.3835 - val_mae: 0.5491 - learning_rate: 1.2500e-04
# Epoch 126/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6958 - mae: 2.1531 - val_loss: 0.3499 - val_mae: 0.5178 - learning_rate: 1.2500e-04
# Epoch 127/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7957 - mae: 2.1710 - val_loss: 0.2965 - val_mae: 0.4802 - learning_rate: 1.2500e-04
# Epoch 128/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6848 - mae: 2.1584 - val_loss: 0.3194 - val_mae: 0.4897 - learning_rate: 1.2500e-04
# Epoch 129/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6953 - mae: 2.1518 - val_loss: 0.3542 - val_mae: 0.5262 - learning_rate: 1.2500e-04
# Epoch 130/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5691 - mae: 2.1417 - val_loss: 0.4493 - val_mae: 0.5895 - learning_rate: 1.2500e-04
# Epoch 131/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6518 - mae: 2.1485 - val_loss: 0.3516 - val_mae: 0.5147 - learning_rate: 1.2500e-04
# Epoch 132/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6480 - mae: 2.1480 - val_loss: 0.3759 - val_mae: 0.5336 - learning_rate: 1.2500e-04
# Epoch 133/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6532 - mae: 2.1541 - val_loss: 0.3445 - val_mae: 0.5104 - learning_rate: 1.2500e-04
# Epoch 134/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6926 - mae: 2.1478 - val_loss: 0.3619 - val_mae: 0.5241 - learning_rate: 1.2500e-04
# Epoch 135/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6563 - mae: 2.1512 - val_loss: 0.3337 - val_mae: 0.4994 - learning_rate: 1.2500e-04
# Epoch 136/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7272 - mae: 2.1554 - val_loss: 0.2766 - val_mae: 0.4559 - learning_rate: 1.2500e-04
# Epoch 137/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6515 - mae: 2.1514 - val_loss: 0.3377 - val_mae: 0.5086 - learning_rate: 1.2500e-04
# Epoch 138/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5840 - mae: 2.1380 - val_loss: 0.3622 - val_mae: 0.5232 - learning_rate: 1.2500e-04
# Epoch 139/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6308 - mae: 2.1444 - val_loss: 0.3346 - val_mae: 0.5091 - learning_rate: 1.2500e-04
# Epoch 140/300
# 102/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5919 - mae: 2.1525
# Epoch 140: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6144 - mae: 2.1529 - val_loss: 0.3035 - val_mae: 0.4844 - learning_rate: 1.2500e-04
# Epoch 141/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4878 - mae: 2.1290 - val_loss: 0.2582 - val_mae: 0.4388 - learning_rate: 6.2500e-05
# Epoch 142/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5688 - mae: 2.1401 - val_loss: 0.4160 - val_mae: 0.5607 - learning_rate: 6.2500e-05
# Epoch 143/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6236 - mae: 2.1467 - val_loss: 0.2877 - val_mae: 0.4665 - learning_rate: 6.2500e-05
# Epoch 144/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5288 - mae: 2.1352 - val_loss: 0.3369 - val_mae: 0.5072 - learning_rate: 6.2500e-05
# Epoch 145/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5183 - mae: 2.1333 - val_loss: 0.3332 - val_mae: 0.5051 - learning_rate: 6.2500e-05
# Epoch 146/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5010 - mae: 2.1277 - val_loss: 0.3558 - val_mae: 0.5118 - learning_rate: 6.2500e-05
# Epoch 147/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6296 - mae: 2.1493 - val_loss: 0.2820 - val_mae: 0.4618 - learning_rate: 6.2500e-05
# Epoch 148/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4638 - mae: 2.1267 - val_loss: 0.3173 - val_mae: 0.4893 - learning_rate: 6.2500e-05
# Epoch 149/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4952 - mae: 2.1316 - val_loss: 0.3525 - val_mae: 0.5146 - learning_rate: 6.2500e-05
# Epoch 150/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5601 - mae: 2.1390 - val_loss: 0.3224 - val_mae: 0.4918 - learning_rate: 6.2500e-05
# Epoch 150: early stopping
# Restoring model weights from the end of the best epoch: 100.

# %% [markdown]
# ## 3.4. Visualizar Curvas de Aprendizado

# %%
# Criar pasta images/MLP se não existir
os.makedirs('images/MLP', exist_ok=True)

# Plotar curvas de loss e MAE
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(history.history['loss'], label='Treino', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validação', linewidth=2)
axes[0].set_xlabel('Época', fontsize=12)
axes[0].set_ylabel('Loss (MSE)', fontsize=12)
axes[0].set_title('Curva de Loss', fontweight='bold', fontsize=14)
axes[0].legend(fontsize=11)
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['mae'], label='Treino', linewidth=2)
axes[1].plot(history.history['val_mae'], label='Validação', linewidth=2)
axes[1].set_xlabel('Época', fontsize=12)
axes[1].set_ylabel('MAE (°C)', fontsize=12)
axes[1].set_title('Curva de MAE', fontweight='bold', fontsize=14)
axes[1].legend(fontsize=11)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('images/MLP/01_curvas_aprendizado.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4. Avaliação do Modelo
#
# ---

# %% [markdown]
# ## 4.1. Métricas no Conjunto de Teste
#
# **Métricas utilizadas:**
# - **MAE** (Mean Absolute Error): Erro médio absoluto em °C
# - **RMSE** (Root Mean Squared Error): Raiz do erro quadrático médio
# - **R²** (Coefficient of Determination): Quanto o modelo explica a variância

# %%
y_pred = model.predict(X_test_scaled, verbose=0)#Fazer predições no conjunto de teste
# Calcular métricas gerais no conjunto de teste
mae_overall = mean_absolute_error(y_test, y_pred)
rmse_overall = np.sqrt(mean_squared_error(y_test, y_pred))
r2_overall = r2_score(y_test, y_pred)

# Calcular MAE por horizonte
mae_t1 = mean_absolute_error(y_test[:, 0], y_pred[:, 0]) #5 minutos
mae_t2 = mean_absolute_error(y_test[:, 1], y_pred[:, 1])#10 minutos
mae_t3 = mean_absolute_error(y_test[:, 2], y_pred[:, 2]) #15 minutos

print(f'\nMétricas Gerais:')
print(f'  MAE:  {mae_overall:.4f} °C')
print(f'  RMSE: {rmse_overall:.4f} °C')
print(f'  R²:   {r2_overall:.4f}')
print(f'\nMAE por Horizonte:')
print(f'  T+10 (5 min):   {mae_t1:.4f} °C')
print(f'  T+19 (10 min):  {mae_t2:.4f} °C')
print(f'  T+29 (15 min):  {mae_t3:.4f} °C')
print(f'\nInformações do Modelo:')
print(f'  Parâmetros totais: {model.count_params():,}')
# Out:
# Métricas Gerais:
#   MAE:  0.3739 °C
#   RMSE: 0.4618 °C
#   R²:   0.9834
#
# MAE por Horizonte:
#   T+10 (5 min):   0.3535 °C
#   T+19 (10 min):  0.3706 °C
#   T+29 (15 min):  0.3976 °C
#
# Informações do Modelo:
#   Parâmetros totais: 1,891

# %% [markdown]
# ## 4.2. Gráficos de Predito vs Real

# %%
# Plotar scatter plots para cada horizonte
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

horizons_names = ['T+10 (5 min)', 'T+19 (10 min)', 'T+29 (15 min)']

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.scatter(y_test[:, i], y_pred[:, i], alpha=0.4, s=15)
    min_val = min(y_test[:, i].min(), y_pred[:, i].min())
    max_val = max(y_test[:, i].max(), y_pred[:, i].max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Ideal')
    ax.set_xlabel('Real (°C)', fontsize=12)
    ax.set_ylabel('Predito (°C)', fontsize=12)
    ax.set_title(horizon_name, fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)
    mae = mean_absolute_error(y_test[:, i], y_pred[:, i])
    r2 = r2_score(y_test[:, i], y_pred[:, i])
    ax.text(0.05, 0.95, f'MAE: {mae:.3f}°C\nR²: {r2:.3f}',
            transform=ax.transAxes, va='top', fontsize=11,
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.7))

plt.tight_layout()
plt.savefig('images/MLP/02_scatter_predictions.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/MLP/02_scatter_predictions.png')
# Out:
# Gráfico salvo: images/MLP/02_scatter_predictions.png

# %% [markdown]
# ## 4.3. Séries Temporais de Predições

# %%
# Plotar série temporal das predições
n_samples = 300
fig, axes = plt.subplots(3, 1, figsize=(16, 12))

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.plot(y_test[:n_samples, i], label='Real', linewidth=2, alpha=0.8)
    ax.plot(y_pred[:n_samples, i], label='Predito', linewidth=2, alpha=0.8)
    ax.set_ylabel('Temperatura (°C)', fontsize=12)
    ax.set_title(horizon_name, fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)

axes[2].set_xlabel('Amostra', fontsize=12)
plt.tight_layout()
plt.savefig('images/MLP/03_timeseries_predictions.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/MLP/03_timeseries_predictions.png')
# Out:
# Gráfico salvo: images/MLP/03_timeseries_predictions.png

# %% [markdown]
# ## 4.4. Análise de Erros

# %%
# Calcular erros
errors = y_pred - y_test

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.hist(errors[:, i], bins=50, alpha=0.7, edgecolor='black')
    ax.axvline(0, color='red', linestyle='--', linewidth=2, label='Erro zero')
    ax.set_xlabel('Erro (°C)', fontsize=12)
    ax.set_ylabel('Frequência', fontsize=12)
    ax.set_title(f'{horizon_name}: Distribuição dos Erros', fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)
    mean_err = errors[:, i].mean()
    std_err = errors[:, i].std()
    ax.text(0.05, 0.95, f'Média: {mean_err:.3f}\nStd: {std_err:.3f}',
            transform=ax.transAxes, va='top', fontsize=11,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.savefig('images/MLP/04_error_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/MLP/04_error_distribution.png')
# Out:
# Gráfico salvo: images/MLP/04_error_distribution.png

# %% [markdown]
# # 5. Conversão para TensorFlow Lite
#
# ---

# %% [markdown]
# ## 5.1. Salvar Modelo Original

# %%
# Criar pasta models/MLP se não existir
os.makedirs('models/MLP', exist_ok=True)

model.save('models/MLP/temperature_model.keras')
print('Modelo Keras salvo: models/MLP/temperature_model.keras')
# Out:
# Modelo Keras salvo: models/MLP/temperature_model.keras

# %% [markdown]
# ## 5.2. Converter para TensorFlow Lite

# %%
# Converter para TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open('models/MLP/temperature_model.tflite', 'wb') as f:
    f.write(tflite_model)

size_kb = len(tflite_model) / 1024
print(f'Modelo TFLite salvo: models/MLP/temperature_model.tflite')
print(f'Tamanho: {size_kb:.2f} KB')

if size_kb < 100:
    print('Compatível com Raspberry Pi Pico (2MB Flash)')
else:
    print('AVISO: Modelo grande para microcontrolador')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Jonas\AppData\Local\Temp\tmpcvwnqcd6\assets
# INFO:tensorflow:Assets written to: C:\Users\Jonas\AppData\Local\Temp\tmpcvwnqcd6\assets
# Saved artifact at 'C:\Users\Jonas\AppData\Local\Temp\tmpcvwnqcd6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 10, 4), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2455162040784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2455162042128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2455162041360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2455162042320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2455162040208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2455162042512: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo TFLite salvo: models/MLP/temperature_model.tflite
# Tamanho: 6.86 KB
# Compatível com Raspberry Pi Pico (2MB Flash)

# %% [markdown]
# ## 5.3. Verificar Conversão TFLite

# %%
# Testar modelo TFLite
interpreter = tf.lite.Interpreter(model_path='models/MLP/temperature_model.tflite')
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print('Informações do modelo TFLite:')
print(f'  Input shape:  {input_details[0]["shape"]}')
print(f'  Input dtype:  {input_details[0]["dtype"]}')
print(f'  Output shape: {output_details[0]["shape"]}')
print(f'  Output dtype: {output_details[0]["dtype"]}')

test_sample = X_test_scaled[0:1].astype(np.float32)
interpreter.set_tensor(input_details[0]['index'], test_sample)
interpreter.invoke()
tflite_pred = interpreter.get_tensor(output_details[0]['index'])

keras_pred = model.predict(test_sample, verbose=0)

print(f'\nTeste de conversão:')
print(f'  Predição Keras:  {keras_pred[0]}')
print(f'  Predição TFLite: {tflite_pred[0]}')
print(f'  Diferença máxima: {np.abs(keras_pred - tflite_pred).max():.6f} °C')

if np.abs(keras_pred - tflite_pred).max() < 0.01:
    print('\nConversão TFLite: OK')
else:
    print('\nAVISO: Diferença significativa após conversão')
# Out:
# Informações do modelo TFLite:
#   Input shape:  [ 1 10  4]
#   Input dtype:  <class 'numpy.float32'>
#   Output shape: [1 3]
#   Output dtype: <class 'numpy.float32'>
#
# Teste de conversão:
#   Predição Keras:  [16.392252 16.390415 16.401855]
#   Predição TFLite: [16.399902 16.398064 16.409496]
#   Diferença máxima: 0.007650 °C
#
# Conversão TFLite: OK

# %% [markdown]
# # 6. Geração de Arquivo C para RP2040
#
# ---

# %% [markdown]
# ## 6.1. Converter Modelo TFLite para C Array

# %%
def convert_to_c_array(tflite_model, var_name='model_data'):#Cria um array de bytes em formato C
    c_array = f"const unsigned char {var_name}[] = {{\n"#array de bytes constante (fica na memória flash)
    for i in range(0, len(tflite_model), 12): # # Percorre de 12 em 12 bytes
        line = "  "
        for j in range(12):## Coloca 12 bytes por linha
            if i + j < len(tflite_model):
                line += f"0x{tflite_model[i+j]:02x}, "## Formato hexadecimal
        c_array += line + "\n"
    c_array += "};\n"
    c_array += f"const unsigned int {var_name}_len = {len(tflite_model)};\n"
    return c_array
#Criação do arquivo .h:
h_content = """// Temperature Prediction Model - TinyML (MLP)
// Auto-generated file - Do not edit manually
// Model trained on AHT20 + BMP280 sensor data

#ifndef TEMPERATURE_MODEL_H
#define TEMPERATURE_MODEL_H

// Model information
#define WINDOW_SIZE 10
#define NUM_FEATURES 4
#define NUM_HORIZONS 3

// Feature names
const char* feature_names[] = {
    "Temp_AHT20_C",
    "Umid_AHT20_pct",
    "Temp_BMP280_C",
    "Press_BMP280_hPa"
};

// Horizon names
const char* horizon_names[] = {
    "5 minutes",
    "10 minutes",
    "15 minutes"
};

"""

h_content += convert_to_c_array(tflite_model, 'temperature_model')#Insere o array de bytes do modelo

h_content += """
#endif // TEMPERATURE_MODEL_H
"""

h_filename = 'models/MLP/temperature_model.h'
with open(h_filename, 'w') as f:
    f.write(h_content)

print(f'Arquivo {h_filename} gerado com sucesso!')
print(f'Tamanho do modelo: {len(tflite_model)} bytes ({len(tflite_model)/1024:.2f} KB)')
# Out:
# Arquivo models/MLP/temperature_model.h gerado com sucesso!
# Tamanho do modelo: 7024 bytes (6.86 KB)

# %% [markdown]
# ## 6.2. Gerar Parâmetros do Scaler para C

# %%
# Gerar arquivo header com parâmetros de normalização
scaler_h_content = """// Scaler parameters for normalization
// Auto-generated file - Do not edit manually

#ifndef SCALER_PARAMS_H
#define SCALER_PARAMS_H

// Mean values
const float scaler_mean[] = {
"""

for i, mean_val in enumerate(scaler.mean_):
    scaler_h_content += f"    {mean_val:.6f}f"
    if i < len(scaler.mean_) - 1:
        scaler_h_content += ","
    scaler_h_content += f"  // {features[i]}\n"

scaler_h_content += """};\n
// Scale values
const float scaler_scale[] = {
"""

for i, scale_val in enumerate(scaler.scale_):
    scaler_h_content += f"    {scale_val:.6f}f"
    if i < len(scaler.scale_) - 1:
        scaler_h_content += ","
    scaler_h_content += f"  // {features[i]}\n"

scaler_h_content += """};\n
#endif // SCALER_PARAMS_H
"""

scaler_filename = 'models/MLP/scaler_params.h'
with open(scaler_filename, 'w') as f:
    f.write(scaler_h_content)

print(f'Arquivo {scaler_filename} gerado com sucesso!')
print(f'\nParâmetros do Scaler:')
print(f'  Mean: {scaler.mean_}')
print(f'  Scale: {scaler.scale_}')
# Out:
# Arquivo models/MLP/scaler_params.h gerado com sucesso!
#
# Parâmetros do Scaler:
#   Mean: [ 20.27610098  66.71863049  21.75954788 918.01528488]
#   Scale: [ 3.29412826 13.48068374  3.19188629  2.10662857]

# %% [markdown]
# ## 6.3. Salvar Scaler

# %%
joblib.dump(scaler, 'models/MLP/scaler.pkl')
print('Scaler salvo: models/MLP/scaler.pkl')
# Out:
# Scaler salvo: models/MLP/scaler.pkl
