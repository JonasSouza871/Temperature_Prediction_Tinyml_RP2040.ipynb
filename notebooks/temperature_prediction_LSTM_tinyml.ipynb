# %% [markdown]
# # Predição de Temperatura com LSTM - TinyML
#
# **Projeto:** Sistema de Predição de Temperatura para Microcontroladores
#
# **Objetivo:** Prever a temperatura do sensor AHT20 em 5, 10 e 15 minutos no futuro
#
# **Sensores utilizados:**
# - AHT20: Temperatura e Umidade
# - BMP280: Temperatura e Pressão
#
# **Modelo:** LSTM (Long Short-Term Memory) compatível com TensorFlow Lite Micro
#
# **Deploy:** Raspberry Pi Pico (RP2040)
#
# ---

# %% [markdown]
# # 1. Carregar os Dados
#
# ---

# %%
# Bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# TensorFlow e Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

# Sklearn para pré-processamento e métricas
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import os
import joblib

# Configuração de visualização
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (14, 6)

# Configurar seed para reprodutibilidade
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f'TensorFlow: {tf.__version__}')
print(f'Seed configurado: {SEED}')
# Out:
# TensorFlow: 2.20.0
# Seed configurado: 42

# %%
#Carregar o dataset de temperatura em lê csv
df_raw = pd.read_csv('data/temp.csv')
df_raw['Timestamp'] = pd.to_datetime(df_raw['Timestamp'])#converter coluna de timestamp para datetime
print(f'Shape original: {df_raw.shape}')
print(f'Colunas disponíveis: {list(df_raw.columns)}')
# Out:
# Shape original: (82430, 12)
# Colunas disponíveis: ['Timestamp', 'Temp_MPU6050_C', 'Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa', 'Temp_BMP180_C', 'Press_BMP180_hPa', 'Temp_DS18B20_C', 'Temp_NTC_C', 'Temp_DHT11_C', 'Umid_DHT11_pct']

# %%
#Selecionar apenas as features de interesse
features = ['Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa']
df = df_raw[['Timestamp'] + features].copy()

print(f'\nDataset filtrado:')
print(f'Shape: {df.shape}')
print(f'Features selecionadas: {features}')
print(f'Período dos dados: {df["Timestamp"].min()} até {df["Timestamp"].max()}')
print(f'\nPrimeiras linhas:')
df.head()
# Out:
# Dataset filtrado:
# Shape: (82430, 5)
# Features selecionadas: ['Temp_AHT20_C', 'Umid_AHT20_pct', 'Temp_BMP280_C', 'Press_BMP280_hPa']
# Período dos dados: 2025-08-31 22:31:02 até 2025-09-30 16:52:09
#
# Primeiras linhas:
#             Timestamp  Temp_AHT20_C  Umid_AHT20_pct  Temp_BMP280_C  \
# 0 2025-08-31 22:31:02         19.90           73.37          21.28
# 1 2025-08-31 22:31:33         19.97           75.57          21.48
# 2 2025-08-31 22:32:05         19.75           74.31          21.25
# 3 2025-08-31 22:32:36         19.55           74.77          21.07
# 4 2025-08-31 22:33:07         19.60           75.09          21.12
#
#    Press_BMP280_hPa
# 0            921.24
# 1            921.12
# 2            921.20
# 3            921.15
# 4            921.25

# %% [markdown]
# # 2. Pré-processamento dos Dados
#
# ---

# %%
# Criar df_clean 
df_clean = df.copy()

#: aplicar remoção de outliers 
for col in features:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]

print(f'Depois: {len(df_clean)} amostras')
removed = len(df) - len(df_clean)
print(f'Removidos: {removed} ({100*removed/len(df):.2f}%)')
# Out:
# Depois: 82430 amostras
# Removidos: 0 (0.00%)

# %% [markdown]
# ## 2.1. Criar Sequências Temporais
#
# **Conceito:** Transformar dados tabulares em sequências 3D para LSTM
#
# **Formato:**
# - Input (X): Janela de 10 timesteps com 4 features cada
# - Output (y): Temperatura futura em 3 horizontes (5, 10, 15 minutos)
#
# **Exemplo:**
# ```
# X = [timestep_0, timestep_1, ..., timestep_9]  <- 10 timesteps passados
# y = [temp_t+10, temp_t+19, temp_t+29]           <- 3 previsões futuras
# ```

# %%
#Configurar parâmetros das sequências
WINDOW_SIZE = 10 #Tamanho janela
HORIZONS = [10, 19, 29] # tempo para cada previsao (5 minutos, 10 minutos, 15 minutos)
print(f'  - Prever temperatura em {HORIZONS[0] * 31 / 60:.1f}, {HORIZONS[1] * 31 / 60:.1f} e {HORIZONS[2] * 31 / 60:.1f} minutos')
# Out:
#   - Prever temperatura em 5.2, 9.8 e 15.0 minutos

# %%
def create_sequences(data, window_size, horizons):
    """
    Criar sequências temporais para treinamento
    
    Parâmetros:
    - data: DataFrame com os dados
    - window_size: tamanho da janela de observação
    - horizons: lista de horizontes de previsão

    Retorna:
    - X: array 3D (samples, timesteps, features) -> Amostras e janelas temporais
    - y: array 2D (samples, horizons) -> TARGET É APENAS OS VALORES DE PREVISAO PARA 5, 10 E 15 MINUTOS
    """
    X, y = [], [] #armazenar x e y
    target = 'Temp_AHT20_C'
    
    for i in range(len(data) - window_size - max(horizons)): #itera pelos dados, parando antes do final para garantir espaço suficiente
        #para a janela + horizonte máximo de previsão
        X.append(data.iloc[i:i+window_size][features].values) #Seleciona apenas as colunas de features 
        #Pega uma janela de tamanho window_size começando na posição i
        y.append([data.iloc[i+window_size+h][target] for h in horizons])#Para cada horizonte em horizons (ex: [0, 5, 10]), pega o valor do target no futuro
        #i+window_size+h = posição após a janela + horizonte
        #Cria uma lista com múltiplos targets (previsões para diferentes tempos futuros)
    
    return np.array(X), np.array(y)

X, y = create_sequences(df_clean, WINDOW_SIZE, HORIZONS) #APLICA FUNÇÃO

print(f'\nX shape: {X.shape}')
print(f'  - {X.shape[0]} amostras')
print(f'  - {X.shape[1]} timesteps por amostra')
print(f'  - {X.shape[2]} features por timestep')
print(f'\ny shape: {y.shape}')
print(f'  - {y.shape[0]} amostras')
print(f'  - {y.shape[1]} horizontes de previsão')
# Out:
# X shape: (82391, 10, 4)
#   - 82391 amostras
#   - 10 timesteps por amostra
#   - 4 features por timestep
#
# y shape: (82391, 3)
#   - 82391 amostras
#   - 3 horizontes de previsão

# %% [markdown]
# ## 2.2. Divisão em Treino, Validação e Teste
#
# **Divisão:**
# - Treino: 70% dos dados (para treinar o modelo)
# - Validação: 15% dos dados (para ajustar hiperparâmetros)
# - Teste: 15% dos dados (para avaliar desempenho final)

# %%
#Dividir dados em treino, validação e teste
train_size = int(0.7 * len(X))
val_size = int(0.85 * len(X))

X_train, y_train = X[:train_size], y[:train_size]
X_val, y_val = X[train_size:val_size], y[train_size:val_size]
X_test, y_test = X[val_size:], y[val_size:]

print('Dados divididos:')
print(f'  Treino:    {len(X_train):6d} amostras ({100*len(X_train)/len(X):.1f}%)')
print(f'  Validação: {len(X_val):6d} amostras ({100*len(X_val)/len(X):.1f}%)')
print(f'  Teste:     {len(X_test):6d} amostras ({100*len(X_test)/len(X):.1f}%)')
# Out:
# Dados divididos:
#   Treino:     57673 amostras (70.0%)
#   Validação:  12359 amostras (15.0%)
#   Teste:      12359 amostras (15.0%)

# %% [markdown]
# ## 2.3. Normalização dos Dados
#
# **Por que normalizar?**
# - Features têm escalas diferentes (temperatura ~20°C, pressão ~920 hPa)
# - Redes neurais aprendem melhor com dados normalizados
# - Evita que features com valores grandes dominem o treinamento
#
# **Método:** StandardScaler (Z-score normalization)
# - Transforma dados para média = 0 e desvio padrão = 1
# - Fórmula: (x - média) / desvio_padrão

# %%
scaler = StandardScaler()# Normalizar dados usando StandardScaler

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #Transforma dados 3D (amostras, timesteps, features) em 2D (amostras*timesteps, features)
#Necessário porque StandardScaler trabalha com dados 2D
scaler.fit(X_train_reshaped) #Calcula média e desvio padrão de cada feature usando APENAS dados de treino
#Aprende os parâmetros de normalização

#aplica (x - média) / desvio para cada feature
# Processo: reshape para 2D → normaliza → reshape de volta para 3D
#Os MESMOS parâmetros aprendidos no treino são aplicados em val e test
X_train_scaled = scaler.transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_val_scaled = scaler.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
print(f'\nParâmetros do scaler:')
print(f'  Média (treino): {X_train_scaled.mean():.6f}')
print(f'  Desvio (treino): {X_train_scaled.std():.6f}')
print(f'\nMédias por feature:')
for i, name in enumerate(features):
    print(f'  {name:20s}: mean={scaler.mean_[i]:8.4f}, std={scaler.scale_[i]:8.4f}')
# Out:
# Parâmetros do scaler:
#   Média (treino): 0.000000
#   Desvio (treino): 1.000000
#
# Médias por feature:
#   Temp_AHT20_C        : mean= 20.2761, std=  3.2941
#   Umid_AHT20_pct      : mean= 66.7186, std= 13.4807
#   Temp_BMP280_C       : mean= 21.7595, std=  3.1919
#   Press_BMP280_hPa    : mean=918.0153, std=  2.1066

# %% [markdown]
# # 3. Construção e Treinamento do Modelo
#
# ---

# %% [markdown]
# ## 3.1. Arquitetura do Modelo LSTM
#
# **Por que LSTM?**
# - Rede recorrente projetada para capturar dependências temporais de longo prazo
# - Possui 3 gates (forget, input, output) que controlam o fluxo de informação
# - Mais robusta que GRU para sequências longas, porém mais pesada
# - Referência clássica em séries temporais
#
# **Arquitetura:**
# ```
# Input (10 timesteps × 4 features)
#     |
# LSTM(24 unidades) + Dropout(0.2)
#     |
# Dense(16) + ReLU + Dropout(0.2)
#     |
# Dense(3) [Output: 3 previsões]
# ```

# %%
# Construir modelo LSTM
model = Sequential([
    # Camada de entrada
    Input(shape=(WINDOW_SIZE, 4)),  #Entrada: janela temporal com 4 features
    
    # Camada LSTM - processa a sequência temporal com 3 gates (forget, input, output)
    # return_sequences=False: retorna apenas o último estado oculto (vetor de 24 valores)
    # Diferente da GRU que tem 2 gates, LSTM tem 3 gates + cell state separado
    LSTM(24,
         kernel_regularizer=regularizers.l2(0.0001),#Regularização L2 para evitar overfitting
         recurrent_regularizer=regularizers.l2(0.0001),#Regularização nos pesos recorrentes
         name='lstm_1'),
    
    #Dropout para reduzir overfitting (desliga 20% dos neurônios)
    Dropout(0.2, name='dropout_1'),
    
    # Camada densa para combinar features extraídas pela LSTM
    Dense(16, activation='relu',
          kernel_regularizer=regularizers.l2(0.0001),
          name='dense_1'),
    
    #Segundo dropout
    Dropout(0.2, name='dropout_2'),
    
    #Camada de saída - 3 valores (previsões para 3 horizontes temporais)
    Dense(3, activation='linear', name='output')
], name='LSTM_Temperature')

# Compilar modelo
# clipnorm=1.0: limita a norma do gradiente para evitar explosão de gradientes (comum em redes recorrentes)
model.compile(
    optimizer=Adam(learning_rate=0.0005, clipnorm=1.0),
    loss='mse',
    metrics=['mae']
)

print('\nArquitetura:')
model.summary()

print(f'\nTotal de parâmetros: {model.count_params():,}')
# Out:
# Arquitetura:
# Model: "LSTM_Temperature"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 24)             │         2,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,235 (12.64 KB)
#  Trainable params: 3,235 (12.64 KB)
#  Non-trainable params: 0 (0.00 B)
# Total de parâmetros: 3,235

# %% [markdown]
# ## 3.2. Configurar Callbacks
#
# **Callbacks** são funções que executam durante o treinamento:
#
# 1. **EarlyStopping**: Para o treinamento se a validação não melhorar
# 2. **ReduceLROnPlateau**: Reduz learning rate quando estagnar

# %%
# Configurar callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=50, #aguarda 50 epocas sem melhora no val_loss antes de parar
        restore_best_weights=True, #restaura pesos da melhor epoca
        verbose=1#mostra quando para
    ), 
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5, #reduz learning rate pela metade
        patience=20, #aguarda 20 epoca sem melhorar antes de reduzir
        min_lr=1e-7, #minimo
        verbose=1 #mostrar quando reduzir
    )
]

# %% [markdown]
# ## 3.3. Treinar o Modelo

# %%
history = model.fit( #treinamento modelo
    X_train_scaled, y_train, # x e y de treino sendo x o normalizado
    validation_data=(X_val_scaled, y_val), #dados de validação
    epochs=300, #300 epoca
    batch_size=512,#Pega 512 amostras do dataset, gradiente mais estavel
    callbacks=callbacks, #Callbacks mostrado acima
    verbose=1 #mostra andamento
)
# Out:
# Epoch 1/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 397.9184 - mae: 19.6842 - val_loss: 429.0518 - val_mae: 20.5578 - learning_rate: 5.0000e-04
# Epoch 2/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 286.3716 - mae: 16.5466 - val_loss: 239.1240 - val_mae: 14.9919 - learning_rate: 5.0000e-04
# Epoch 3/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 119.4341 - mae: 9.4543 - val_loss: 66.8394 - val_mae: 6.8806 - learning_rate: 5.0000e-04
# Epoch 4/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 35.9565 - mae: 4.6779 - val_loss: 9.2383 - val_mae: 2.2470 - learning_rate: 5.0000e-04
# Epoch 5/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 20.3444 - mae: 3.5417 - val_loss: 3.3675 - val_mae: 1.5789 - learning_rate: 5.0000e-04
# Epoch 6/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 17.4966 - mae: 3.3035 - val_loss: 2.0392 - val_mae: 1.2072 - learning_rate: 5.0000e-04
# Epoch 7/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 15.7575 - mae: 3.1332 - val_loss: 1.5959 - val_mae: 1.1099 - learning_rate: 5.0000e-04
# Epoch 8/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 14.6669 - mae: 3.0246 - val_loss: 0.7633 - val_mae: 0.6693 - learning_rate: 5.0000e-04
# Epoch 9/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 13.7952 - mae: 2.9327 - val_loss: 0.8474 - val_mae: 0.7755 - learning_rate: 5.0000e-04
# Epoch 10/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 13.1341 - mae: 2.8539 - val_loss: 0.4548 - val_mae: 0.5155 - learning_rate: 5.0000e-04
# Epoch 11/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 12.7027 - mae: 2.8104 - val_loss: 0.8053 - val_mae: 0.7916 - learning_rate: 5.0000e-04
# Epoch 12/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 12.1282 - mae: 2.7495 - val_loss: 0.8219 - val_mae: 0.8224 - learning_rate: 5.0000e-04
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 11.7571 - mae: 2.7090 - val_loss: 0.4956 - val_mae: 0.6242 - learning_rate: 5.0000e-04
# Epoch 14/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 11.5595 - mae: 2.6739 - val_loss: 0.6108 - val_mae: 0.7031 - learning_rate: 5.0000e-04
# Epoch 15/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 11.3144 - mae: 2.6477 - val_loss: 0.6473 - val_mae: 0.7477 - learning_rate: 5.0000e-04
# Epoch 16/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 11.0310 - mae: 2.6140 - val_loss: 0.4373 - val_mae: 0.5863 - learning_rate: 5.0000e-04
# Epoch 17/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10.9759 - mae: 2.6079 - val_loss: 0.3907 - val_mae: 0.5504 - learning_rate: 5.0000e-04
# Epoch 18/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10.8304 - mae: 2.5857 - val_loss: 0.3388 - val_mae: 0.5015 - learning_rate: 5.0000e-04
# Epoch 19/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10.6643 - mae: 2.5643 - val_loss: 0.6081 - val_mae: 0.7195 - learning_rate: 5.0000e-04
# Epoch 20/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 10.3972 - mae: 2.5324 - val_loss: 0.6011 - val_mae: 0.6989 - learning_rate: 5.0000e-04
# Epoch 21/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 10.2363 - mae: 2.5172 - val_loss: 0.2661 - val_mae: 0.4114 - learning_rate: 5.0000e-04
# Epoch 22/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10.2905 - mae: 2.5190 - val_loss: 0.4339 - val_mae: 0.5926 - learning_rate: 5.0000e-04
# Epoch 23/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10.1158 - mae: 2.4971 - val_loss: 0.3848 - val_mae: 0.5481 - learning_rate: 5.0000e-04
# Epoch 24/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.9025 - mae: 2.4725 - val_loss: 0.4530 - val_mae: 0.6149 - learning_rate: 5.0000e-04
# Epoch 25/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.8830 - mae: 2.4634 - val_loss: 0.2679 - val_mae: 0.4258 - learning_rate: 5.0000e-04
# Epoch 26/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.6344 - mae: 2.4349 - val_loss: 0.3925 - val_mae: 0.5592 - learning_rate: 5.0000e-04
# Epoch 27/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.6995 - mae: 2.4345 - val_loss: 0.5896 - val_mae: 0.7073 - learning_rate: 5.0000e-04
# Epoch 28/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.3977 - mae: 2.4031 - val_loss: 0.3630 - val_mae: 0.5333 - learning_rate: 5.0000e-04
# Epoch 29/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.2300 - mae: 2.3811 - val_loss: 0.2789 - val_mae: 0.4427 - learning_rate: 5.0000e-04
# Epoch 30/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.1319 - mae: 2.3665 - val_loss: 0.4399 - val_mae: 0.5972 - learning_rate: 5.0000e-04
# Epoch 31/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.0120 - mae: 2.3421 - val_loss: 0.5464 - val_mae: 0.6727 - learning_rate: 5.0000e-04
# Epoch 32/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.9720 - mae: 2.3452 - val_loss: 0.3991 - val_mae: 0.5684 - learning_rate: 5.0000e-04
# Epoch 33/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.7905 - mae: 2.3135 - val_loss: 0.3191 - val_mae: 0.4894 - learning_rate: 5.0000e-04
# Epoch 34/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5610 - mae: 2.2887 - val_loss: 0.3273 - val_mae: 0.5033 - learning_rate: 5.0000e-04
# Epoch 35/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 8.5232 - mae: 2.2798 - val_loss: 0.2900 - val_mae: 0.4648 - learning_rate: 5.0000e-04
# Epoch 36/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.3020 - mae: 2.2519 - val_loss: 0.2619 - val_mae: 0.4384 - learning_rate: 5.0000e-04
# Epoch 37/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.2749 - mae: 2.2463 - val_loss: 0.2395 - val_mae: 0.4132 - learning_rate: 5.0000e-04
# Epoch 38/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1294 - mae: 2.2263 - val_loss: 0.3229 - val_mae: 0.4914 - learning_rate: 5.0000e-04
# Epoch 39/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 8.0374 - mae: 2.2165 - val_loss: 0.2970 - val_mae: 0.4626 - learning_rate: 5.0000e-04
# Epoch 40/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.0528 - mae: 2.2123 - val_loss: 0.1973 - val_mae: 0.3675 - learning_rate: 5.0000e-04
# Epoch 41/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.8614 - mae: 2.1842 - val_loss: 0.3773 - val_mae: 0.5524 - learning_rate: 5.0000e-04
# Epoch 42/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.7731 - mae: 2.1792 - val_loss: 0.2627 - val_mae: 0.4450 - learning_rate: 5.0000e-04
# Epoch 43/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6973 - mae: 2.1627 - val_loss: 0.4064 - val_mae: 0.5701 - learning_rate: 5.0000e-04
# Epoch 44/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5327 - mae: 2.1383 - val_loss: 0.3237 - val_mae: 0.4985 - learning_rate: 5.0000e-04
# Epoch 45/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 7.5069 - mae: 2.1364 - val_loss: 0.2896 - val_mae: 0.4684 - learning_rate: 5.0000e-04
# Epoch 46/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.4533 - mae: 2.1279 - val_loss: 0.3058 - val_mae: 0.4806 - learning_rate: 5.0000e-04
# Epoch 47/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.3618 - mae: 2.1138 - val_loss: 0.5006 - val_mae: 0.6349 - learning_rate: 5.0000e-04
# Epoch 48/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.3043 - mae: 2.1067 - val_loss: 0.2831 - val_mae: 0.4533 - learning_rate: 5.0000e-04
# Epoch 49/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.2209 - mae: 2.0963 - val_loss: 0.5446 - val_mae: 0.6521 - learning_rate: 5.0000e-04
# Epoch 50/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1527 - mae: 2.0840 - val_loss: 0.3363 - val_mae: 0.5054 - learning_rate: 5.0000e-04
# Epoch 51/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1062 - mae: 2.0793 - val_loss: 0.2348 - val_mae: 0.4121 - learning_rate: 5.0000e-04
# Epoch 52/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1164 - mae: 2.0758 - val_loss: 0.2517 - val_mae: 0.4319 - learning_rate: 5.0000e-04
# Epoch 53/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0531 - mae: 2.0661 - val_loss: 0.3011 - val_mae: 0.4810 - learning_rate: 5.0000e-04
# Epoch 54/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.9840 - mae: 2.0578 - val_loss: 0.3480 - val_mae: 0.5145 - learning_rate: 5.0000e-04
# Epoch 55/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.9316 - mae: 2.0506 - val_loss: 0.0922 - val_mae: 0.2209 - learning_rate: 5.0000e-04
# Epoch 56/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.8414 - mae: 2.0349 - val_loss: 0.2200 - val_mae: 0.3917 - learning_rate: 5.0000e-04
# Epoch 57/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 6.8233 - mae: 2.0301 - val_loss: 0.1710 - val_mae: 0.3311 - learning_rate: 5.0000e-04
# Epoch 58/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 6.7440 - mae: 2.0176 - val_loss: 0.2939 - val_mae: 0.4578 - learning_rate: 5.0000e-04
# Epoch 59/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7537 - mae: 2.0262 - val_loss: 0.3543 - val_mae: 0.5124 - learning_rate: 5.0000e-04
# Epoch 60/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7352 - mae: 2.0229 - val_loss: 0.2662 - val_mae: 0.4363 - learning_rate: 5.0000e-04
# Epoch 61/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7116 - mae: 2.0177 - val_loss: 0.1646 - val_mae: 0.3130 - learning_rate: 5.0000e-04
# Epoch 62/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5689 - mae: 1.9970 - val_loss: 0.1711 - val_mae: 0.3339 - learning_rate: 5.0000e-04
# Epoch 63/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5163 - mae: 1.9901 - val_loss: 0.2245 - val_mae: 0.3983 - learning_rate: 5.0000e-04
# Epoch 64/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4758 - mae: 1.9786 - val_loss: 0.2940 - val_mae: 0.4609 - learning_rate: 5.0000e-04
# Epoch 65/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 6.4435 - mae: 1.9747 - val_loss: 0.2839 - val_mae: 0.4436 - learning_rate: 5.0000e-04
# Epoch 66/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4759 - mae: 1.9822 - val_loss: 0.4276 - val_mae: 0.5735 - learning_rate: 5.0000e-04
# Epoch 67/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4113 - mae: 1.9704 - val_loss: 0.1812 - val_mae: 0.3390 - learning_rate: 5.0000e-04
# Epoch 68/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3446 - mae: 1.9617 - val_loss: 0.2514 - val_mae: 0.4205 - learning_rate: 5.0000e-04
# Epoch 69/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3798 - mae: 1.9665 - val_loss: 0.2341 - val_mae: 0.3946 - learning_rate: 5.0000e-04
# Epoch 70/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3356 - mae: 1.9623 - val_loss: 0.2118 - val_mae: 0.3810 - learning_rate: 5.0000e-04
# Epoch 71/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2537 - mae: 1.9471 - val_loss: 0.2870 - val_mae: 0.4540 - learning_rate: 5.0000e-04
# Epoch 72/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.1657 - mae: 1.9309 - val_loss: 0.3033 - val_mae: 0.4782 - learning_rate: 5.0000e-04
# Epoch 73/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.1604 - mae: 1.9303 - val_loss: 0.2972 - val_mae: 0.4581 - learning_rate: 5.0000e-04
# Epoch 74/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.1209 - mae: 1.9259 - val_loss: 0.2617 - val_mae: 0.4278 - learning_rate: 5.0000e-04
# Epoch 75/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1282 - mae: 1.9282
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.0907 - mae: 1.9202 - val_loss: 0.1425 - val_mae: 0.2845 - learning_rate: 5.0000e-04
# Epoch 76/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.1120 - mae: 1.9264 - val_loss: 0.1866 - val_mae: 0.3401 - learning_rate: 2.5000e-04
# Epoch 77/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9987 - mae: 1.9023 - val_loss: 0.2530 - val_mae: 0.4178 - learning_rate: 2.5000e-04
# Epoch 78/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0608 - mae: 1.9129 - val_loss: 0.1720 - val_mae: 0.3297 - learning_rate: 2.5000e-04
# Epoch 79/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 6.0572 - mae: 1.9169 - val_loss: 0.1978 - val_mae: 0.3533 - learning_rate: 2.5000e-04
# Epoch 80/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 5.9489 - mae: 1.8941 - val_loss: 0.2485 - val_mae: 0.4265 - learning_rate: 2.5000e-04
# Epoch 81/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0452 - mae: 1.9151 - val_loss: 0.2956 - val_mae: 0.4593 - learning_rate: 2.5000e-04
# Epoch 82/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9936 - mae: 1.9056 - val_loss: 0.2541 - val_mae: 0.4209 - learning_rate: 2.5000e-04
# Epoch 83/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9469 - mae: 1.8965 - val_loss: 0.2439 - val_mae: 0.4085 - learning_rate: 2.5000e-04
# Epoch 84/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9383 - mae: 1.8960 - val_loss: 0.3540 - val_mae: 0.5043 - learning_rate: 2.5000e-04
# Epoch 85/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8879 - mae: 1.8931 - val_loss: 0.3304 - val_mae: 0.4869 - learning_rate: 2.5000e-04
# Epoch 86/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.8852 - mae: 1.8828 - val_loss: 0.3244 - val_mae: 0.4768 - learning_rate: 2.5000e-04
# Epoch 87/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8649 - mae: 1.8835 - val_loss: 0.2766 - val_mae: 0.4326 - learning_rate: 2.5000e-04
# Epoch 88/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9604 - mae: 1.8951 - val_loss: 0.1841 - val_mae: 0.3330 - learning_rate: 2.5000e-04
# Epoch 89/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8276 - mae: 1.8762 - val_loss: 0.2452 - val_mae: 0.4034 - learning_rate: 2.5000e-04
# Epoch 90/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7789 - mae: 1.8739 - val_loss: 0.2443 - val_mae: 0.4064 - learning_rate: 2.5000e-04
# Epoch 91/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8730 - mae: 1.8856 - val_loss: 0.2378 - val_mae: 0.3987 - learning_rate: 2.5000e-04
# Epoch 92/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7517 - mae: 1.8635 - val_loss: 0.2979 - val_mae: 0.4614 - learning_rate: 2.5000e-04
# Epoch 93/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7690 - mae: 1.8632 - val_loss: 0.2502 - val_mae: 0.4075 - learning_rate: 2.5000e-04
# Epoch 94/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8007 - mae: 1.8718 - val_loss: 0.1735 - val_mae: 0.3349 - learning_rate: 2.5000e-04
# Epoch 95/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7692 - mae: 1.8689
# Epoch 95: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.6824 - mae: 1.8541 - val_loss: 0.2525 - val_mae: 0.4054 - learning_rate: 2.5000e-04
# Epoch 96/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8187 - mae: 1.8706 - val_loss: 0.2276 - val_mae: 0.3813 - learning_rate: 1.2500e-04
# Epoch 97/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6497 - mae: 1.8491 - val_loss: 0.2265 - val_mae: 0.3802 - learning_rate: 1.2500e-04
# Epoch 98/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7112 - mae: 1.8571 - val_loss: 0.2440 - val_mae: 0.4050 - learning_rate: 1.2500e-04
# Epoch 99/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6798 - mae: 1.8520 - val_loss: 0.2710 - val_mae: 0.4324 - learning_rate: 1.2500e-04
# Epoch 100/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7434 - mae: 1.8600 - val_loss: 0.2271 - val_mae: 0.3899 - learning_rate: 1.2500e-04
# Epoch 101/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6894 - mae: 1.8518 - val_loss: 0.2568 - val_mae: 0.4199 - learning_rate: 1.2500e-04
# Epoch 102/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6992 - mae: 1.8563 - val_loss: 0.2231 - val_mae: 0.3850 - learning_rate: 1.2500e-04
# Epoch 103/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6542 - mae: 1.8497 - val_loss: 0.2856 - val_mae: 0.4462 - learning_rate: 1.2500e-04
# Epoch 104/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6793 - mae: 1.8519 - val_loss: 0.2176 - val_mae: 0.3760 - learning_rate: 1.2500e-04
# Epoch 105/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5824 - mae: 1.8383 - val_loss: 0.2330 - val_mae: 0.3968 - learning_rate: 1.2500e-04
# Epoch 105: early stopping
# Restoring model weights from the end of the best epoch: 55.

# %% [markdown]
# ## 3.4. Visualizar Curvas de Aprendizado

# %%
# Criar pasta images/LSTM se não existir
os.makedirs('images/LSTM', exist_ok=True)

# Plotar curvas de loss e MAE
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(history.history['loss'], label='Treino', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validação', linewidth=2)
axes[0].set_xlabel('Época', fontsize=12)
axes[0].set_ylabel('Loss (MSE)', fontsize=12)
axes[0].set_title('Curva de Loss', fontweight='bold', fontsize=14)
axes[0].legend(fontsize=11)
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['mae'], label='Treino', linewidth=2)
axes[1].plot(history.history['val_mae'], label='Validação', linewidth=2)
axes[1].set_xlabel('Época', fontsize=12)
axes[1].set_ylabel('MAE (°C)', fontsize=12)
axes[1].set_title('Curva de MAE', fontweight='bold', fontsize=14)
axes[1].legend(fontsize=11)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('images/LSTM/01_curvas_aprendizado.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4. Avaliação do Modelo
#
# ---

# %% [markdown]
# ## 4.1. Métricas no Conjunto de Teste
#
# **Métricas utilizadas:**
# - **MAE** (Mean Absolute Error): Erro médio absoluto em °C
# - **RMSE** (Root Mean Squared Error): Raiz do erro quadrático médio
# - **R²** (Coefficient of Determination): Quanto o modelo explica a variância

# %%
y_pred = model.predict(X_test_scaled, verbose=0)#Fazer predições no conjunto de teste
# Calcular métricas gerais no conjunto de teste
mae_overall = mean_absolute_error(y_test, y_pred)
rmse_overall = np.sqrt(mean_squared_error(y_test, y_pred))
r2_overall = r2_score(y_test, y_pred)

# Calcular MAE por horizonte
mae_t1 = mean_absolute_error(y_test[:, 0], y_pred[:, 0]) #5 minutos
mae_t2 = mean_absolute_error(y_test[:, 1], y_pred[:, 1])#10 minutos
mae_t3 = mean_absolute_error(y_test[:, 2], y_pred[:, 2]) #15 minutos

print(f'\nMétricas Gerais:')
print(f'  MAE:  {mae_overall:.4f} °C')
print(f'  RMSE: {rmse_overall:.4f} °C')
print(f'  R²:   {r2_overall:.4f}')
print(f'\nMAE por Horizonte:')
print(f'  T+10 (5 min):   {mae_t1:.4f} °C')
print(f'  T+19 (10 min):  {mae_t2:.4f} °C')
print(f'  T+29 (15 min):  {mae_t3:.4f} °C')
print(f'\nInformações do Modelo:')
print(f'  Parâmetros totais: {model.count_params():,}')
# Out:
# Métricas Gerais:
#   MAE:  0.3264 °C
#   RMSE: 0.3913 °C
#   R²:   0.9881
#
# MAE por Horizonte:
#   T+10 (5 min):   0.2987 °C
#   T+19 (10 min):  0.3173 °C
#   T+29 (15 min):  0.3634 °C
#
# Informações do Modelo:
#   Parâmetros totais: 3,235

# %% [markdown]
# ## 4.2. Gráficos de Predito vs Real

# %%
# Plotar scatter plots para cada horizonte
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

horizons_names = ['T+10 (5 min)', 'T+19 (10 min)', 'T+29 (15 min)']

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.scatter(y_test[:, i], y_pred[:, i], alpha=0.4, s=15)
    min_val = min(y_test[:, i].min(), y_pred[:, i].min())
    max_val = max(y_test[:, i].max(), y_pred[:, i].max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Ideal')
    ax.set_xlabel('Real (°C)', fontsize=12)
    ax.set_ylabel('Predito (°C)', fontsize=12)
    ax.set_title(horizon_name, fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)
    mae = mean_absolute_error(y_test[:, i], y_pred[:, i])
    r2 = r2_score(y_test[:, i], y_pred[:, i])
    ax.text(0.05, 0.95, f'MAE: {mae:.3f}°C\nR²: {r2:.3f}',
            transform=ax.transAxes, va='top', fontsize=11,
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.7))

plt.tight_layout()
plt.savefig('images/LSTM/02_scatter_predictions.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/LSTM/02_scatter_predictions.png')
# Out:
# Gráfico salvo: images/LSTM/02_scatter_predictions.png

# %% [markdown]
# ## 4.3. Séries Temporais de Predições

# %%
# Plotar série temporal das predições
n_samples = 300
fig, axes = plt.subplots(3, 1, figsize=(16, 12))

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.plot(y_test[:n_samples, i], label='Real', linewidth=2, alpha=0.8)
    ax.plot(y_pred[:n_samples, i], label='Predito', linewidth=2, alpha=0.8)
    ax.set_ylabel('Temperatura (°C)', fontsize=12)
    ax.set_title(horizon_name, fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)

axes[2].set_xlabel('Amostra', fontsize=12)
plt.tight_layout()
plt.savefig('images/LSTM/03_timeseries_predictions.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/LSTM/03_timeseries_predictions.png')
# Out:
# Gráfico salvo: images/LSTM/03_timeseries_predictions.png

# %% [markdown]
# ## 4.4. Análise de Erros

# %%
# Calcular erros
errors = y_pred - y_test

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, (horizon_name, ax) in enumerate(zip(horizons_names, axes)):
    ax.hist(errors[:, i], bins=50, alpha=0.7, edgecolor='black')
    ax.axvline(0, color='red', linestyle='--', linewidth=2, label='Erro zero')
    ax.set_xlabel('Erro (°C)', fontsize=12)
    ax.set_ylabel('Frequência', fontsize=12)
    ax.set_title(f'{horizon_name}: Distribuição dos Erros', fontweight='bold', fontsize=14)
    ax.legend(fontsize=11)
    ax.grid(True, alpha=0.3)
    mean_err = errors[:, i].mean()
    std_err = errors[:, i].std()
    ax.text(0.05, 0.95, f'Média: {mean_err:.3f}\nStd: {std_err:.3f}',
            transform=ax.transAxes, va='top', fontsize=11,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.savefig('images/LSTM/04_error_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print('Gráfico salvo: images/LSTM/04_error_distribution.png')
# Out:
# Gráfico salvo: images/LSTM/04_error_distribution.png

# %% [markdown]
# # 5. Salvar Modelo
#
# ---

# %%
# Criar pasta models/LSTM se não existir
os.makedirs('models/LSTM', exist_ok=True)

# Salvar modelo Keras
model.save('models/LSTM/temperature_model.keras')
print('Modelo Keras salvo: models/LSTM/temperature_model.keras')

# Salvar scaler
joblib.dump(scaler, 'models/LSTM/scaler.pkl')
print('Scaler salvo: models/LSTM/scaler.pkl')
# Out:
# Modelo Keras salvo: models/LSTM/temperature_model.keras
# Scaler salvo: models/LSTM/scaler.pkl
